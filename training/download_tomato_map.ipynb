# %%
print(True)
# Out:
# True

# %%
from huggingface_hub import snapshot_download

save_dir = "/mnt/data/tomatoMAP"

snapshot_download(
    repo_id="Voxel51/tomato-map",
    repo_type="dataset",
    local_dir=save_dir,
)

print("Đã tải vào:", save_dir)
# Out:
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 68075 files:   0%|          | 0/68075 [00:00<?, ?it/s]

# %%
# import fiftyone as fo
# from fiftyone.utils.huggingface import load_from_hub

# # Load the dataset
# # Note: other available arguments include 'max_samples', etc
# dataset = load_from_hub("Voxel51/tomato-map")

# # Launch the App
# session = fo.launch_app(dataset)
# Out:
# Downloading config file fiftyone.yml from Voxel51/tomato-map
# Loading dataset
# Importing samples...
#  100% |█████████████| 68069/68069 [1.7s elapsed, 0s remaining, 39.7K samples/s]
# Downloading 4679 media files...
#  38%|███████████████████████████▌                                            | 18/47 [15:55<38:06, 78.84s/it]

# %%
# Out:
# Hint: The `hf-cli` skill is not installed. Run `hf skills add -g --claude` to teach your AI agents how to use the `hf` CLI.
# ? How would you like to log in?  [Use arrows, Enter to confirm]
# > Log in with your browser
#   Paste an access token
#
# Aborted!
